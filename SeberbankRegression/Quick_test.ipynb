# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error as mse

cd ..

train = pd.read_csv('data/train_clean.csv')
test = pd.read_csv('data/test_clean.csv')

col = list(test.columns)[2:]
label = np.log1p(train['price_doc'])
dtrain = xgb.DMatrix(train[col],label)

params = {
   'eta': 0.05, ## Try 0.01,3,5
   'max_depth': 5,## Try 4,5,6
   'subsample': 0.7,
   'colsample_bytree': 0.7,
   'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'silent': 1
}
xgb_cvalid = xgb.cv(params, dtrain, num_boost_round=1000, early_stopping_rounds=20,
     verbose_eval=50, show_stdv=True,seed=42)

kf = KFold(n_splits=5,shuffle=False)
col = list(test.columns)[2:]
train_array = train[col].as_matrix()
label = np.log1p(train['price_doc']).as_matrix()
accuracy = []

for train_index, test_index in kf.split(train_array):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = train_array[train_index,:], train_array[test_index,:]
    y_train, y_test = label[train_index], label[test_index]
    dtrain = xgb.DMatrix(X_train,y_train)
    dtest = xgb.DMatrix(X_test)
    model = xgb.train(params,dtrain,num_boost_round=len(xgb_cvalid))
    print('training done')
    pred = model.predict(dtest)
    RMSLE = mse(y_test, pred)**0.5
    print('RMSLE: '+str(RMSLE))
    accuracy.append(RMSLE)
    
accuracy

print accuracy
print "mean\tstd"
print np.array(accuracy).mean(), np.array(accuracy).std()

# %%
train = pd.read_csv('data/train_clean_subsample_avg_price.csv')
test = pd.read_csv('data/test_clean_subsample_avg_price.csv')

# %% [markdown]
# # Use avg as feature

# %%
drop_col = ['moscow_avg_price_avg', 'moscow_avg_price_high', 'moscow_avg_price_low', 'sub_area_avg_price']
drop_col = ["{}_{}".format(col, currency) for currency in ['usd', 'eur'] for col in drop_col]
drop_col
train = train.drop(drop_col, axis=1)
test = test.drop(drop_col, axis=1)
# Out:
# ['moscow_avg_price_avg_usd',
#  'moscow_avg_price_high_usd',
#  'moscow_avg_price_low_usd',
#  'sub_area_avg_price_usd',
#  'moscow_avg_price_avg_eur',
#  'moscow_avg_price_high_eur',
#  'moscow_avg_price_low_eur',
#  'sub_area_avg_price_eur']

# %%
def get_avg_price_features(df):
    df['avg_subarea_moscow_avg_diff'] = df['sub_area_avg_price_rub'] - df['moscow_avg_price_avg_rub']
    df['avg_subarea_moscow_avg_ratio'] = (df['sub_area_avg_price_rub'] - df['moscow_avg_price_avg_rub'])/df['moscow_avg_price_avg_rub']

# %%
train.head().T
# Out:
#                                                  0            1            2  \
# id                                               1            2            3
# timestamp                               2011-08-20   2011-08-23   2011-08-27
# full_sq                                         43           34           43
# life_sq                                         27           19           29
# floor                                            4            3            2
# max_floor                                      NaN          NaN          NaN
# material                                       NaN          NaN          NaN
# build_year                                     NaN          NaN          NaN
# num_room                                       NaN          NaN          NaN
# kitch_sq                                       NaN          NaN          NaN
# state                                          NaN          NaN          NaN
# product_type                                     0            0            0
# sub_area                                         9           70          128
# area_m                                 6.40758e+06  9.58934e+06  4.80827e+06
# raion_popul                                 155572       115352       101708
# green_zone_part                           0.189727     0.372602      0.11256
# indust_part                            6.99893e-05    0.0496373     0.118537
# children_preschool                            9576         6880         5879
# preschool_quota                               5001         3119         1463
# preschool_education_centers_raion                5            5            4
# children_school                              10309         7759         6207
# school_quota                                 11065         6237         5580
# school_education_centers_raion                   5            8            7
# school_education_centers_top_20_raion            0            0            0
# hospital_beds_raion                            240          229         1183
# healthcare_centers_raion                         1            1            1
# university_top_20_raion                          0            0            0
# sport_objects_raion                              7            6            5
# additional_education_raion                       3            1            1
# culture_objects_top_25                           0            1            0
# ...                                            ...          ...          ...
# church_count_5000                               22           29           27
# mosque_count_5000                                1            1            0
# leisure_count_5000                               0           10            4
# sport_count_5000                                52           66           67
# market_count_5000                                4           14           10
# price_doc                                  5850000      6000000      5700000
# month_year_cnt                                   3            3            3
# week_year_cnt                                    1            2            2
# month                                            8            8            8
# dow                                              5            1            5
# rel_floor                                      NaN          NaN          NaN
# rel_floor_rev                                  NaN          NaN          NaN
# rel_kitch_sq                                   NaN          NaN          NaN
# room_size                                      NaN          NaN          NaN
# ratio_preschool                           0.928807     0.886598     0.947004
# extra_area                                      16           15           14
# floor_ratio                                    NaN          NaN          NaN
# room_avg_size                                  NaN          NaN          NaN
# moscow_avg_price_avg_eur                   3622.69      3636.38      3654.63
# moscow_avg_price_avg_rub                    150106       151034       152434
# moscow_avg_price_avg_usd                   5125.01      5126.28      5127.99
# moscow_avg_price_high_eur                  5259.93      5289.13      5328.07
# moscow_avg_price_high_rub                   217854       219653       222525
# moscow_avg_price_high_usd                  7475.84      7482.87      7492.24
# moscow_avg_price_low_eur                   2776.84      2784.57      2794.88
# moscow_avg_price_low_rub                    115711       116441       117415
# moscow_avg_price_low_usd                   3917.49      3918.37      3919.54
# sub_area_avg_price_eur                     2913.06      2910.26      2910.54
# sub_area_avg_price_rub                      120917       120994       121213
# sub_area_avg_price_usd                     4182.83      4186.27      4190.86
#
#                                                  3            4
# id                                               4            5
# timestamp                               2011-09-01   2011-09-05
# full_sq                                         89           77
# life_sq                                         50           77
# floor                                            9            4
# max_floor                                      NaN          NaN
# material                                       NaN          NaN
# build_year                                     NaN          NaN
# num_room                                       NaN          NaN
# kitch_sq                                       NaN          NaN
# state                                          NaN          NaN
# product_type                                     0            0
# sub_area                                        65            6
# area_m                                 1.25835e+07  8.39846e+06
# raion_popul                                 178473       108171
# green_zone_part                           0.194703    0.0152337
# indust_part                              0.0697534    0.0373165
# children_preschool                           13087         5706
# preschool_quota                               6839         3240
# preschool_education_centers_raion                9            7
# children_school                              13670         6748
# school_quota                                 17063         7770
# school_education_centers_raion                  10            9
# school_education_centers_top_20_raion            0            0
# hospital_beds_raion                            NaN          562
# healthcare_centers_raion                         1            4
# university_top_20_raion                          0            2
# sport_objects_raion                             17           25
# additional_education_raion                       6            2
# culture_objects_top_25                           0            0
# ...                                            ...          ...
# church_count_5000                                4          236
# mosque_count_5000                                0            2
# leisure_count_5000                               0           91
# sport_count_5000                                26          195
# market_count_5000                                3           14
# price_doc                                 13100000     16331452
# month_year_cnt                                  38           38
# week_year_cnt                                    1            5
# month                                            9            9
# dow                                              3            0
# rel_floor                                      NaN          NaN
# rel_floor_rev                                  NaN          NaN
# rel_kitch_sq                                   NaN          NaN
# room_size                                      NaN          NaN
# ratio_preschool                           0.957282     0.845459
# extra_area                                      39            0
# floor_ratio                                    NaN          NaN
# room_avg_size                                  NaN          NaN
# moscow_avg_price_avg_eur                   3677.45       3695.7
# moscow_avg_price_avg_rub                    154185       155586
# moscow_avg_price_avg_usd                   5130.12      5122.45
# moscow_avg_price_high_eur                  5376.74      5415.68
# moscow_avg_price_high_rub                   226114       228986
# moscow_avg_price_high_usd                  7503.96      7494.23
# moscow_avg_price_low_eur                   2807.77      2807.77
# moscow_avg_price_low_rub                    118632       119058
# moscow_avg_price_low_usd                      3921      3900.32
# sub_area_avg_price_eur                     2925.91       2938.2
# sub_area_avg_price_rub                      121923       122491
# sub_area_avg_price_usd                     4194.29      4194.29
#
# [316 rows x 5 columns]

# %%
params = {
   'eta': 0.05, ## Try 0.01,3,5
   'max_depth': 5,## Try 4,5,6
   'subsample': 0.7,
   'colsample_bytree': 0.7,
   'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'silent': 1
}
xgb_cvalid = xgb.cv(params, dtrain, num_boost_round=1000, early_stopping_rounds=20,
     verbose_eval=50, show_stdv=True,seed=42)
# Out:
# [0]	train-rmse:14.4049+0.00178946	test-rmse:14.405+0.00341215
# [50]	train-rmse:1.16136+0.000284672	test-rmse:1.16777+0.0031281
# [100]	train-rmse:0.307942+0.00119694	test-rmse:0.351326+0.0038784
# [150]	train-rmse:0.274377+0.00103711	test-rmse:0.337475+0.00446533
# [200]	train-rmse:0.258275+0.00151799	test-rmse:0.336864+0.00437301

# %%
kf = KFold(n_splits=5,shuffle=False)
col = list(test.columns)[2:]
train_array = train[col].as_matrix()
label = np.log1p(train['price_doc']).as_matrix()
accuracy = []

for train_index, test_index in kf.split(train_array):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = train_array[train_index,:], train_array[test_index,:]
    y_train, y_test = label[train_index], label[test_index]
    dtrain = xgb.DMatrix(X_train,y_train)
    dtest = xgb.DMatrix(X_test)
    model = xgb.train(params,dtrain,num_boost_round=len(xgb_cvalid))
    print('training done')
    pred = model.predict(dtest)
    RMSLE = mse(y_test, pred)**0.5
    print('RMSLE: '+str(RMSLE))
    accuracy.append(RMSLE)
    
accuracy
# Out:
# ('TRAIN:', array([ 5853,  5854,  5855, ..., 29259, 29260, 29261]), 'TEST:', array([   0,    1,    2, ..., 5850, 5851, 5852]))
# training done
# RMSLE: 0.384004819482
# ('TRAIN:', array([    0,     1,     2, ..., 29259, 29260, 29261]), 'TEST:', array([ 5853,  5854,  5855, ..., 11703, 11704, 11705]))
# training done
# RMSLE: 0.318389721533
# ('TRAIN:', array([    0,     1,     2, ..., 29259, 29260, 29261]), 'TEST:', array([11706, 11707, 11708, ..., 17555, 17556, 17557]))
# training done
# RMSLE: 0.332483655834
# ('TRAIN:', array([    0,     1,     2, ..., 29259, 29260, 29261]), 'TEST:', array([17558, 17559, 17560, ..., 23407, 23408, 23409]))
# training done
# RMSLE: 0.322626565997
# ('TRAIN:', array([    0,     1,     2, ..., 23407, 23408, 23409]), 'TEST:', array([23410, 23411, 23412, ..., 29259, 29260, 29261]))
# training done
# RMSLE: 0.308389251332
# [0.38400481948200516,
#  0.31838972153259376,
#  0.33248365583403999,
#  0.32262656599650258,
#  0.30838925133226203]

# %%
train_file = 'data/train_clean_subsample_avg_price.csv'
test_file = 'data/train_clean_subsample_avg_price.csv'

train = pd.read_csv(train_file)
test = pd.read_csv(test_file)

# %%
train.columns.tolist()
# Out:
# ['id',
#  'timestamp',
#  'full_sq',
#  'life_sq',
#  'floor',
#  'max_floor',
#  'material',
#  'build_year',
#  'num_room',
#  'kitch_sq',
#  'state',
#  'product_type',
#  'sub_area',
#  'area_m',
#  'raion_popul',
#  'green_zone_part',
#  'indust_part',
#  'children_preschool',
#  'preschool_quota',
#  'preschool_education_centers_raion',
#  'children_school',
#  'school_quota',
#  'school_education_centers_raion',
#  'school_education_centers_top_20_raion',
#  'hospital_beds_raion',
#  'healthcare_centers_raion',
#  'university_top_20_raion',
#  'sport_objects_raion',
#  'additional_education_raion',
#  'culture_objects_top_25',
#  'culture_objects_top_25_raion',
#  'shopping_centers_raion',
#  'office_raion',
#  'thermal_power_plant_raion',
#  'incineration_raion',
#  'oil_chemistry_raion',
#  'radiation_raion',
#  'railroad_terminal_raion',
#  'big_market_raion',
#  'nuclear_reactor_raion',
#  'detention_facility_raion',
#  'full_all',
#  'male_f',
#  'female_f',
#  'young_all',
#  'young_male',
#  'young_female',
#  'work_all',
#  'work_male',
#  'work_female',
#  'ekder_all',
#  'ekder_male',
#  'ekder_female',
#  '0_6_all',
#  '0_6_male',
#  '0_6_female',
#  '7_14_all',
#  '7_14_male',
#  '7_14_female',
#  '0_17_all',
#  '0_17_male',
#  '0_17_female',
#  '16_29_all',
#  '16_29_male',
#  '16_29_female',
#  '0_13_all',
#  '0_13_male',
#  '0_13_female',
#  'raion_build_count_with_material_info',
#  'build_count_block',
#  'build_count_wood',
#  'build_count_frame',
#  'build_count_brick',
#  'build_count_monolith',
#  'build_count_panel',
#  'build_count_foam',
#  'build_count_slag',
#  'build_count_mix',
#  'raion_build_count_with_builddate_info',
#  'build_count_before_1920',
#  'build_count_1921-1945',
#  'build_count_1946-1970',
#  'build_count_1971-1995',
#  'build_count_after_1995',
#  'ID_metro',
#  'metro_min_avto',
#  'metro_km_avto',
#  'metro_min_walk',
#  'metro_km_walk',
#  'kindergarten_km',
#  'school_km',
#  'park_km',
#  'green_zone_km',
#  'industrial_km',
#  'water_treatment_km',
#  'cemetery_km',
#  'incineration_km',
#  'railroad_station_walk_km',
#  'railroad_station_walk_min',
#  'ID_railroad_station_walk',
#  'railroad_station_avto_km',
#  'railroad_station_avto_min',
#  'ID_railroad_station_avto',
#  'public_transport_station_km',
#  'public_transport_station_min_walk',
#  'water_km',
#  'water_1line',
#  'mkad_km',
#  'ttk_km',
#  'sadovoe_km',
#  'bulvar_ring_km',
#  'kremlin_km',
#  'big_road1_km',
#  'ID_big_road1',
#  'big_road1_1line',
#  'big_road2_km',
#  'ID_big_road2',
#  'railroad_km',
#  'railroad_1line',
#  'zd_vokzaly_avto_km',
#  'ID_railroad_terminal',
#  'bus_terminal_avto_km',
#  'ID_bus_terminal',
#  'oil_chemistry_km',
#  'nuclear_reactor_km',
#  'radiation_km',
#  'power_transmission_line_km',
#  'thermal_power_plant_km',
#  'ts_km',
#  'big_market_km',
#  'market_shop_km',
#  'fitness_km',
#  'swim_pool_km',
#  'ice_rink_km',
#  'stadium_km',
#  'basketball_km',
#  'hospice_morgue_km',
#  'detention_facility_km',
#  'public_healthcare_km',
#  'university_km',
#  'workplaces_km',
#  'shopping_centers_km',
#  'office_km',
#  'additional_education_km',
#  'preschool_km',
#  'big_church_km',
#  'church_synagogue_km',
#  'mosque_km',
#  'theater_km',
#  'museum_km',
#  'exhibition_km',
#  'catering_km',
#  'ecology',
#  'green_part_500',
#  'prom_part_500',
#  'office_count_500',
#  'office_sqm_500',
#  'trc_count_500',
#  'trc_sqm_500',
#  'cafe_count_500',
#  'cafe_sum_500_min_price_avg',
#  'cafe_sum_500_max_price_avg',
#  'cafe_avg_price_500',
#  'cafe_count_500_na_price',
#  'cafe_count_500_price_500',
#  'cafe_count_500_price_1000',
#  'cafe_count_500_price_1500',
#  'cafe_count_500_price_2500',
#  'cafe_count_500_price_4000',
#  'cafe_count_500_price_high',
#  'big_church_count_500',
#  'church_count_500',
#  'mosque_count_500',
#  'leisure_count_500',
#  'sport_count_500',
#  'market_count_500',
#  'green_part_1000',
#  'prom_part_1000',
#  'office_count_1000',
#  'office_sqm_1000',
#  'trc_count_1000',
#  'trc_sqm_1000',
#  'cafe_count_1000',
#  'cafe_sum_1000_min_price_avg',
#  'cafe_sum_1000_max_price_avg',
#  'cafe_avg_price_1000',
#  'cafe_count_1000_na_price',
#  'cafe_count_1000_price_500',
#  'cafe_count_1000_price_1000',
#  'cafe_count_1000_price_1500',
#  'cafe_count_1000_price_2500',
#  'cafe_count_1000_price_4000',
#  'cafe_count_1000_price_high',
#  'big_church_count_1000',
#  'church_count_1000',
#  'mosque_count_1000',
#  'leisure_count_1000',
#  'sport_count_1000',
#  'market_count_1000',
#  'green_part_1500',
#  'prom_part_1500',
#  'office_count_1500',
#  'office_sqm_1500',
#  'trc_count_1500',
#  'trc_sqm_1500',
#  'cafe_count_1500',
#  'cafe_sum_1500_min_price_avg',
#  'cafe_sum_1500_max_price_avg',
#  'cafe_avg_price_1500',
#  'cafe_count_1500_na_price',
#  'cafe_count_1500_price_500',
#  'cafe_count_1500_price_1000',
#  'cafe_count_1500_price_1500',
#  'cafe_count_1500_price_2500',
#  'cafe_count_1500_price_4000',
#  'cafe_count_1500_price_high',
#  'big_church_count_1500',
#  'church_count_1500',
#  'mosque_count_1500',
#  'leisure_count_1500',
#  'sport_count_1500',
#  'market_count_1500',
#  'green_part_2000',
#  'prom_part_2000',
#  'office_count_2000',
#  'office_sqm_2000',
#  'trc_count_2000',
#  'trc_sqm_2000',
#  'cafe_count_2000',
#  'cafe_sum_2000_min_price_avg',
#  'cafe_sum_2000_max_price_avg',
#  'cafe_avg_price_2000',
#  'cafe_count_2000_na_price',
#  'cafe_count_2000_price_500',
#  'cafe_count_2000_price_1000',
#  'cafe_count_2000_price_1500',
#  'cafe_count_2000_price_2500',
#  'cafe_count_2000_price_4000',
#  'cafe_count_2000_price_high',
#  'big_church_count_2000',
#  'church_count_2000',
#  'mosque_count_2000',
#  'leisure_count_2000',
#  'sport_count_2000',
#  'market_count_2000',
#  'green_part_3000',
#  'prom_part_3000',
#  'office_count_3000',
#  'office_sqm_3000',
#  'trc_count_3000',
#  'trc_sqm_3000',
#  'cafe_count_3000',
#  'cafe_sum_3000_min_price_avg',
#  'cafe_sum_3000_max_price_avg',
#  'cafe_avg_price_3000',
#  'cafe_count_3000_na_price',
#  'cafe_count_3000_price_500',
#  'cafe_count_3000_price_1000',
#  'cafe_count_3000_price_1500',
#  'cafe_count_3000_price_2500',
#  'cafe_count_3000_price_4000',
#  'cafe_count_3000_price_high',
#  'big_church_count_3000',
#  'church_count_3000',
#  'mosque_count_3000',
#  'leisure_count_3000',
#  'sport_count_3000',
#  'market_count_3000',
#  'green_part_5000',
#  'prom_part_5000',
#  'office_count_5000',
#  'office_sqm_5000',
#  'trc_count_5000',
#  'trc_sqm_5000',
#  'cafe_count_5000',
#  'cafe_sum_5000_min_price_avg',
#  'cafe_sum_5000_max_price_avg',
#  'cafe_avg_price_5000',
#  'cafe_count_5000_na_price',
#  'cafe_count_5000_price_500',
#  'cafe_count_5000_price_1000',
#  'cafe_count_5000_price_1500',
#  'cafe_count_5000_price_2500',
#  'cafe_count_5000_price_4000',
#  'cafe_count_5000_price_high',
#  'big_church_count_5000',
#  'church_count_5000',
#  'mosque_count_5000',
#  'leisure_count_5000',
#  'sport_count_5000',
#  'market_count_5000',
#  'price_doc',
#  'month_year_cnt',
#  'week_year_cnt',
#  'month',
#  'dow',
#  'rel_floor',
#  'rel_floor_rev',
#  'rel_kitch_sq',
#  'room_size',
#  'ratio_preschool',
#  'extra_area',
#  'floor_ratio',
#  'room_avg_size',
#  'moscow_avg_price_avg_eur',
#  'moscow_avg_price_avg_rub',
#  'moscow_avg_price_avg_usd',
#  'moscow_avg_price_high_eur',
#  'moscow_avg_price_high_rub',
#  'moscow_avg_price_high_usd',
#  'moscow_avg_price_low_eur',
#  'moscow_avg_price_low_rub',
#  'moscow_avg_price_low_usd',
#  'sub_area_avg_price_eur',
#  'sub_area_avg_price_rub',
#  'sub_area_avg_price_usd']

# %%
import sys
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error as mse
from scipy import stats
from sklearn import preprocessing

"""
feature type:
0: direct use price
1. drop other currency
2. add different and ratio
3. add different and ratio, and statistics features
"""

train_file = 'data/train_clean_subsample_avg_price.csv'
test_file = 'data/test_clean_subsample_avg_price.csv'

train = pd.read_csv(train_file)
test = pd.read_csv(test_file)

def drop_other_currency(df):
    drop_col = ['moscow_avg_price_avg', 'moscow_avg_price_high', 'moscow_avg_price_low', 'sub_area_avg_price']
    drop_col = ["{}_{}".format(col, currency) for currency in ['usd', 'eur'] for col in drop_col]
    return df.drop(drop_col, axis=1)

def get_avg_price_comparison_features(df):
    df['avg_subarea_moscow_avg_diff'] = df['sub_area_avg_price_rub'] - df['moscow_avg_price_avg_rub']
    df['avg_subarea_moscow_avg_ratio'] = (df['sub_area_avg_price_rub'] - df['moscow_avg_price_avg_rub'])/df['moscow_avg_price_avg_rub']
    return df


min_max_scaler = preprocessing.MinMaxScaler()

def get_slop(y):
    x = np.array(range(len(y)))
    slope, intercept, r_value, p_value, slope_std_error = stats.linregress(x, y)
    return slope

def get_avg_price_stat(df, columns):
    df_copy = pd.DataFrame()
    span_list = [7, 30, 90, 180]
    for t in span_list:
        for col_name in columns:
            df_copy['{}_mean_{}'.format(col_name, t)] = df[col_name].rolling(window=t).mean()
            df_copy['{}_std_{}'.format(col_name, t)] = df[col_name].rolling(window=t).std()
            df_copy['{}_norm'.format(col_name)] =  min_max_scaler.fit_transform(df[col_name])
            df_copy['{}_slope_{}'.format(col_name, t)] = df_copy['{}_norm'.format(col_name)].rolling(window=t).apply(get_slop)
            df_copy = df_copy.drop(['{}_norm'.format(col_name)], axis=1)
    return df_copy

feature_type = 3

if feature_type == 0:
    pass

if feature_type >= 1:
    train = drop_other_currency(train)
    test = drop_other_currency(test)

if feature_type >= 2:
    train = get_avg_price_comparison_features(train)
    test = get_avg_price_comparison_features(test)

if feature_type >= 3:
    train = get_avg_price_stat(train, ['sub_area_avg_price_rub', 'moscow_avg_price_avg_rub'])
    test = get_avg_price_stat(test, ['sub_area_avg_price_rub', 'moscow_avg_price_avg_rub'])
# Out:
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-aeb2149b8372> in <module>()
#      67 if feature_type >= 3:
#      68     train = get_avg_price_stat(train, ['sub_area_avg_price_rub', 'moscow_avg_price_avg_rub'])
# ---> 69     test = get_avg_price_stat(test, ['sub_area_avg_price_rub', 'moscow_avg_price_avg_rub'])
#
# <ipython-input-37-aeb2149b8372> in get_avg_price_stat(df, columns)
#      47             df_copy['{}_mean_{}'.format(col_name, t)] = df[col_name].rolling(window=t).mean()
#      48             df_copy['{}_std_{}'.format(col_name, t)] = df[col_name].rolling(window=t).std()
# ---> 49             df_copy['{}_norm'.format(col_name)] =  min_max_scaler.fit_transform(df[col_name])
#      50             df_copy['{}_slope_{}'.format(col_name, t)] = df_copy['{}_norm'.format(col_name)].rolling(window=t).apply(get_slop)
#      51             df_copy = df_copy.drop(['{}_norm'.format(col_name)], axis=1)
#
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/base.pyc in fit_transform(self, X, y, **fit_params)
#     492         if y is None:
#     493             # fit method of arity 1 (unsupervised transformation)
# --> 494             return self.fit(X, **fit_params).transform(X)
#     495         else:
#     496             # fit method of arity 2 (supervised transformation)
#
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.pyc in fit(self, X, y)
#     290         # Reset internal state before fitting
#     291         self._reset()
# --> 292         return self.partial_fit(X, y)
#     293
#     294     def partial_fit(self, X, y=None):
#
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.pyc in partial_fit(self, X, y)
#     316
#     317         X = check_array(X, copy=self.copy, ensure_2d=False, warn_on_dtype=True,
# --> 318                         estimator=self, dtype=FLOAT_DTYPES)
#     319
#     320         if X.ndim == 1:
#
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     405                              % (array.ndim, estimator_name))
#     406         if force_all_finite:
# --> 407             _assert_all_finite(array)
#     408
#     409     shape_repr = _shape_repr(array.shape)
#
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/utils/validation.pyc in _assert_all_finite(X)
#      56             and not np.isfinite(X).all()):
#      57         raise ValueError("Input contains NaN, infinity"
# ---> 58                          " or a value too large for %r." % X.dtype)
#      59
#      60
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
train = get_avg_price_stat(train, ['sub_area_avg_price_rub', 'moscow_avg_price_avg_rub'])
# Out:
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %%
sum(pd.isnull(test ['sub_area_avg_price_rub']))
      #, 'moscow_avg_price_avg_rub']
# Out:
# 4003

# %%
train[np.isfinite(train)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-ff6f8f655762> in <module>()
# ----> 1 train[np.isfinite(train)]
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
col = list(test.columns)[2:]
label = np.log1p(train['price_doc'])
dtrain = xgb.DMatrix(train[col],label)

params = {
'eta': 0.05, ## Try 0.01,3,5
'max_depth': 5,## Try 4,5,6
'subsample': 0.7,
'colsample_bytree': 0.7,
'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'silent': 1
}
xgb_cvalid = xgb.cv(params, dtrain, num_boost_round=1000, early_stopping_rounds=20,
    verbose_eval=50, show_stdv=True,seed=42, nfold=5)

print "xgboost round: {}".format(len(xgb_cvalid))

kf = KFold(n_splits=5,shuffle=False)
col = list(test.columns)[2:]
train_array = train[col].as_matrix()
label = np.log1p(train['price_doc']).as_matrix()
accuracy = []

for train_index, test_index in kf.split(train_array):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = train_array[train_index,:], train_array[test_index,:]
    y_train, y_test = label[train_index], label[test_index]
    dtrain = xgb.DMatrix(X_train,y_train)
    dtest = xgb.DMatrix(X_test)
    model = xgb.train(params,dtrain,num_boost_round=len(xgb_cvalid))
    print('training done')
    pred = model.predict(dtest)
    RMSLE = mse(y_test, pred)**0.5
    print('RMSLE: '+str(RMSLE))
    accuracy.append(RMSLE)

accuracy

print accuracy
print "mean\tstd"
print np.array(accuracy).mean(), np.array(accuracy).std()


def get_feature_importance(model):
    Importance = model.get_fscore()
    Importance = list(Importance.items())
    Feature= []
    Score = []
    for each in Importance:
        Feature.append(each[0])
        Score.append(each[1])
    df = pd.DataFrame({'Feature':Feature,'Score':Score}).sort_values(by=['Score'],ascending=[0])
    return df

f_imp = get_feature_importance(model)
print f_imp

# %%
import sys
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error as mse
from scipy import stats
from sklearn import preprocessing

"""
feature type:
0: direct use price
1. drop other currency
2. add different and ratio
3. add different and ratio, and avg statistics features
"""

train_file = 'data/train_clean_subsample_avg_price.csv'
test_file = 'data/test_clean_subsample_avg_price.csv'

train = pd.read_csv(train_file)
test = pd.read_csv(test_file)

def drop_other_currency(df):
    drop_col = ['moscow_avg_price_avg', 'moscow_avg_price_high', 'moscow_avg_price_low', 'sub_area_avg_price']
    drop_col = ["{}_{}".format(col, currency) for currency in ['usd', 'eur'] for col in drop_col]
    return df.drop(drop_col, axis=1)

def get_avg_price_comparison_features(df):
    df['avg_subarea_moscow_avg_diff'] = df['sub_area_avg_price_rub'] - df['moscow_avg_price_avg_rub']
    df['avg_subarea_moscow_avg_ratio'] = (df['sub_area_avg_price_rub'] - df['moscow_avg_price_avg_rub'])/df['moscow_avg_price_avg_rub']
    return df


def add_moscow_price_stat(df):
    moscow_avg_price = pd.read_csv(prepath+'moscow_avg_price_with_stat.csv')
    df.timestamp = pd.to_datetime(df.timestamp, infer_datetime_format=True)
    moscow_avg_price = moscow_avg_price.rename(columns={'timestamp':'t_timestamp'})
    df['date'] = df['timestamp'].apply(lambda x: x.strftime('%Y-%m-%d'))
    df = df.merge(moscow_avg_price, left_on='date', right_on='t_timestamp').drop(['date', 't_timestamp'], axis=1)
    return df

3

if feature_type == 0:
    pass

if feature_type >= 1:
    train = drop_other_currency(train)
    test = drop_other_currency(test)

if feature_type >= 2:
    train = get_avg_price_comparison_features(train)
    test = get_avg_price_comparison_features(test)

if feature_type >= 3:
    train = add_moscow_price_stat(train)
    test = add_moscow_price_stat(test)

# %%
col = list(test.columns)[2:]
label = np.log1p(train['price_doc'])
dtrain = xgb.DMatrix(train[col],label)

params = {
'eta': 0.05, ## Try 0.01,3,5
'max_depth': 5,## Try 4,5,6
'subsample': 0.7,
'colsample_bytree': 0.7,
'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'silent': 1
}
xgb_cvalid = xgb.cv(params, dtrain, num_boost_round=1000, early_stopping_rounds=20,
    verbose_eval=50, show_stdv=True,seed=42, nfold=5)

print "xgboost round: {}".format(len(xgb_cvalid))

kf = KFold(n_splits=5,shuffle=False)
col = list(test.columns)[2:]
train_array = train[col].as_matrix()
label = np.log1p(train['price_doc']).as_matrix()
accuracy = []

for train_index, test_index in kf.split(train_array):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = train_array[train_index,:], train_array[test_index,:]
    y_train, y_test = label[train_index], label[test_index]
    dtrain = xgb.DMatrix(X_train,y_train)
    dtest = xgb.DMatrix(X_test)
    model = xgb.train(params,dtrain,num_boost_round=len(xgb_cvalid))
    print('training done')
    pred = model.predict(dtest)
    RMSLE = mse(y_test, pred)**0.5
    print('RMSLE: '+str(RMSLE))
    accuracy.append(RMSLE)

accuracy

print accuracy
print "mean\tstd"
print np.array(accuracy).mean(), np.array(accuracy).std()


def get_feature_importance(model):
    Importance = model.get_fscore()
    Importance = list(Importance.items())
    Feature= []
    Score = []
    for each in Importance:
        Feature.append(each[0])
        Score.append(each[1])
    df = pd.DataFrame({'Feature':Feature,'Score':Score}).sort_values(by=['Score'],ascending=[0])
    return df

f_imp = get_feature_importance(model)
print f_imp


"""
direct

[0]	train-rmse:14.427+0.00330067	test-rmse:14.427+0.00742354
[50]	train-rmse:1.1624+0.000801421	test-rmse:1.16658+0.00543451
[100]	train-rmse:0.317574+0.00357707	test-rmse:0.344896+0.00726594
[150]	train-rmse:0.288764+0.00380459	test-rmse:0.329274+0.00883175
[200]	train-rmse:0.276291+0.0036066	test-rmse:0.327643+0.00879625
[250]	train-rmse:0.266411+0.00323442	test-rmse:0.327148+0.00842217
[300]	train-rmse:0.257561+0.00340931	test-rmse:0.326993+0.00800119
('TRAIN:', array([ 5853,  5854,  5855, ..., 29259, 29260, 29261]), 'TEST:', array([   0,    1,    2, ..., 5850, 5851, 5852]))
training done
RMSLE: 0.383017101562
('TRAIN:', array([    0,     1,     2, ..., 29259, 29260, 29261]), 'TEST:', array([ 5853,  5854,  5855, ..., 11703, 11704, 11705]))
training done
RMSLE: 0.313228510103
('TRAIN:', array([    0,     1,     2, ..., 29259, 29260, 29261]), 'TEST:', array([11706, 11707, 11708, ..., 17555, 17556, 17557]))
training done
RMSLE: 0.330456779999
('TRAIN:', array([    0,     1,     2, ..., 29259, 29260, 29261]), 'TEST:', array([17558, 17559, 17560, ..., 23407, 23408, 23409]))
training done
RMSLE: 0.322327986334
('TRAIN:', array([    0,     1,     2, ..., 23407, 23408, 23409]), 'TEST:', array([23410, 23411, 23412, ..., 29259, 29260, 29261]))
training done
RMSLE: 0.320165030776
[0.38301710156174595, 0.31322851010289504, 0.33045677999895751, 0.32232798633397974, 0.32016503077598907]
mean	std
0.333839081755 0.0251960244843
"""


"""
1. drop other currency
[0]	train-rmse:14.427+0.00167013	test-rmse:14.427+0.0071428
[50]	train-rmse:1.16191+0.000549938	test-rmse:1.16602+0.00476997
[100]	train-rmse:0.320419+0.00202003	test-rmse:0.34418+0.00723171
[150]	train-rmse:0.293878+0.00229244	test-rmse:0.328318+0.009073
[200]	train-rmse:0.282967+0.002239	test-rmse:0.326741+0.00933618
[250]	train-rmse:0.274054+0.00228758	test-rmse:0.325941+0.00941562
[300]	train-rmse:0.265922+0.0025173	test-rmse:0.32563+0.00927432
[350]	train-rmse:0.258777+0.00253456	test-rmse:0.325466+0.00946576
xgboost round: 350
('TRAIN:', array([ 5853,  5854,  5855, ..., 29259, 29260, 29261]), 'TEST:', array([   0,    1,    2, ..., 5850, 5851, 5852]))
training done
RMSLE: 0.383769717317
('TRAIN:', array([    0,     1,     2, ..., 29259, 29260, 29261]), 'TEST:', array([ 5853,  5854,  5855, ..., 11703, 11704, 11705]))
training done
RMSLE: 0.313193736375
('TRAIN:', array([    0,     1,     2, ..., 29259, 29260, 29261]), 'TEST:', array([11706, 11707, 11708, ..., 17555, 17556, 17557]))
training done
RMSLE: 0.332085268764
('TRAIN:', array([    0,     1,     2, ..., 29259, 29260, 29261]), 'TEST:', array([17558, 17559, 17560, ..., 23407, 23408, 23409]))
training done
RMSLE: 0.321253921226
('TRAIN:', array([    0,     1,     2, ..., 23407, 23408, 23409]), 'TEST:', array([23410, 23411, 23412, ..., 29259, 29260, 29261]))
training done
RMSLE: 0.302037854381
[0.38376971731671189, 0.31319373637465714, 0.33208526876408434, 0.32125392122648716, 0.30203785438076636]
mean	std
0.330468099613 0.0284086650108
"""



"""
2. add different and ratio
[0]	train-rmse:14.427+0.00167013	test-rmse:14.427+0.0071428
[50]	train-rmse:1.16179+0.000576531	test-rmse:1.1655+0.00449047
[100]	train-rmse:0.320246+0.00201104	test-rmse:0.344001+0.00754858
[150]	train-rmse:0.293562+0.00193066	test-rmse:0.328398+0.00943655
[200]	train-rmse:0.282715+0.00206784	test-rmse:0.32672+0.00957286
[250]	train-rmse:0.273669+0.0022386	test-rmse:0.326108+0.009504
xgboost round: 271
('TRAIN:', array([ 5853,  5854,  5855, ..., 29259, 29260, 29261]), 'TEST:', array([   0,    1,    2, ..., 5850, 5851, 5852]))
training done
RMSLE: 0.38314368611
('TRAIN:', array([    0,     1,     2, ..., 29259, 29260, 29261]), 'TEST:', array([ 5853,  5854,  5855, ..., 11703, 11704, 11705]))
training done
RMSLE: 0.314605651939
('TRAIN:', array([    0,     1,     2, ..., 29259, 29260, 29261]), 'TEST:', array([11706, 11707, 11708, ..., 17555, 17556, 17557]))
training done
RMSLE: 0.331218417307
('TRAIN:', array([    0,     1,     2, ..., 29259, 29260, 29261]), 'TEST:', array([17558, 17559, 17560, ..., 23407, 23408, 23409]))
training done
RMSLE: 0.320997076729
('TRAIN:', array([    0,     1,     2, ..., 23407, 23408, 23409]), 'TEST:', array([23410, 23411, 23412, ..., 29259, 29260, 29261]))
training done
RMSLE: 0.304352344435
[0.3831436861101189, 0.31460565193924533, 0.33121841730725859, 0.32099707672850647, 0.30435234443486026]
mean	std
0.330863435304 0.0275602943639
"""
# Out:
# [0]	train-rmse:14.4271+0.00168388	test-rmse:14.4271+0.00692365
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-6a5b5aaf333f> in <module>()
#      13 }
#      14 xgb_cvalid = xgb.cv(params, dtrain, num_boost_round=1000, early_stopping_rounds=20,
# ---> 15     verbose_eval=50, show_stdv=True,seed=42, nfold=5)
#      16
#      17 print "xgboost round: {}".format(len(xgb_cvalid))
#
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/xgboost/training.pyc in cv(params, dtrain, num_boost_round, nfold, stratified, folds, metrics, obj, feval, maximize, early_stopping_rounds, fpreproc, as_pandas, verbose_eval, show_stdv, seed, callbacks)
#     399         for fold in cvfolds:
#     400             fold.update(i, obj)
# --> 401         res = aggcv([f.eval(i, feval) for f in cvfolds])
#     402
#     403         for key, mean, std in res:
#
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/xgboost/training.pyc in eval(self, iteration, feval)
#     221     def eval(self, iteration, feval):
#     222         """"Evaluate the CVPack for one iteration."""
# --> 223         return self.bst.eval_set(self.watchlist, iteration, feval)
#     224
#     225
#
# /Users/zhesun/.virtualenvs/venv2/lib/python2.7/site-packages/xgboost/core.pyc in eval_set(self, evals, iteration, feval)
#     865             _check_call(_LIB.XGBoosterEvalOneIter(self.handle, iteration,
#     866                                                   dmats, evnames, len(evals),
# --> 867                                                   ctypes.byref(msg)))
#     868             return msg.value
#     869         else:
#
# KeyboardInterrupt:

# %%
train.head().T
# Out:
#                                                          0  \
# id                                                       1
# timestamp                              2011-08-20 00:00:00
# full_sq                                                 43
# life_sq                                                 27
# floor                                                    4
# max_floor                                              NaN
# material                                               NaN
# build_year                                             NaN
# num_room                                               NaN
# kitch_sq                                               NaN
# state                                                  NaN
# product_type                                             0
# sub_area                                                 9
# area_m                                         6.40758e+06
# raion_popul                                         155572
# green_zone_part                                   0.189727
# indust_part                                    6.99893e-05
# children_preschool                                    9576
# preschool_quota                                       5001
# preschool_education_centers_raion                        5
# children_school                                      10309
# school_quota                                         11065
# school_education_centers_raion                           5
# school_education_centers_top_20_raion                    0
# hospital_beds_raion                                    240
# healthcare_centers_raion                                 1
# university_top_20_raion                                  0
# sport_objects_raion                                      7
# additional_education_raion                               3
# culture_objects_top_25                                   0
# ...                                                    ...
# moscow_avg_price_low_eur_slope_7                0.00144471
# moscow_avg_price_low_eur_slope_90              0.000549198
# moscow_avg_price_low_eur_std_180                   62.9343
# moscow_avg_price_low_eur_std_30                    13.1968
# moscow_avg_price_low_eur_std_7                     5.56885
# moscow_avg_price_low_eur_std_90                    26.3997
# moscow_avg_price_low_rub_mean_180                   107558
# moscow_avg_price_low_rub_mean_30                    112808
# moscow_avg_price_low_rub_mean_7                     114981
# moscow_avg_price_low_rub_mean_90                    110175
# moscow_avg_price_low_rub_slope_180              0.00113892
# moscow_avg_price_low_rub_slope_30               0.00314334
# moscow_avg_price_low_rub_slope_7                  0.004662
# moscow_avg_price_low_rub_slope_90                0.0015159
# moscow_avg_price_low_rub_std_180                   3175.01
# moscow_avg_price_low_rub_std_30                    1475.25
# moscow_avg_price_low_rub_std_7                     525.731
# moscow_avg_price_low_rub_std_90                    2171.23
# moscow_avg_price_low_usd_mean_180                  3808.11
# moscow_avg_price_low_usd_mean_30                   3914.27
# moscow_avg_price_low_usd_mean_7                    3916.61
# moscow_avg_price_low_usd_mean_90                   3891.35
# moscow_avg_price_low_usd_slope_180             0.000714419
# moscow_avg_price_low_usd_slope_30              5.91048e-05
# moscow_avg_price_low_usd_slope_7               0.000112575
# moscow_avg_price_low_usd_slope_90              0.000363894
# moscow_avg_price_low_usd_std_180                   100.284
# moscow_avg_price_low_usd_std_30                    1.49964
# moscow_avg_price_low_usd_std_7                    0.632824
# moscow_avg_price_low_usd_std_90                    26.5166
#
#                                                          1  \
# id                                                       2
# timestamp                              2011-08-23 00:00:00
# full_sq                                                 34
# life_sq                                                 19
# floor                                                    3
# max_floor                                              NaN
# material                                               NaN
# build_year                                             NaN
# num_room                                               NaN
# kitch_sq                                               NaN
# state                                                  NaN
# product_type                                             0
# sub_area                                                70
# area_m                                         9.58934e+06
# raion_popul                                         115352
# green_zone_part                                   0.372602
# indust_part                                      0.0496373
# children_preschool                                    6880
# preschool_quota                                       3119
# preschool_education_centers_raion                        5
# children_school                                       7759
# school_quota                                          6237
# school_education_centers_raion                           8
# school_education_centers_top_20_raion                    0
# hospital_beds_raion                                    229
# healthcare_centers_raion                                 1
# university_top_20_raion                                  0
# sport_objects_raion                                      6
# additional_education_raion                               1
# culture_objects_top_25                                   1
# ...                                                    ...
# moscow_avg_price_low_eur_slope_7                0.00144471
# moscow_avg_price_low_eur_slope_90              0.000557499
# moscow_avg_price_low_eur_std_180                   63.9695
# moscow_avg_price_low_eur_std_30                    16.1223
# moscow_avg_price_low_eur_std_7                     5.56885
# moscow_avg_price_low_eur_std_90                    26.8534
# moscow_avg_price_low_rub_mean_180                   107779
# moscow_avg_price_low_rub_mean_30                    113331
# moscow_avg_price_low_rub_mean_7                     115711
# moscow_avg_price_low_rub_mean_90                    110461
# moscow_avg_price_low_rub_slope_180              0.00117933
# moscow_avg_price_low_rub_slope_30               0.00353887
# moscow_avg_price_low_rub_slope_7                  0.004662
# moscow_avg_price_low_rub_slope_90               0.00165199
# moscow_avg_price_low_rub_std_180                   3305.28
# moscow_avg_price_low_rub_std_30                    1653.65
# moscow_avg_price_low_rub_std_7                     525.731
# moscow_avg_price_low_rub_std_90                    2374.39
# moscow_avg_price_low_usd_mean_180                  3813.63
# moscow_avg_price_low_usd_mean_30                   3914.76
# moscow_avg_price_low_usd_mean_7                    3917.49
# moscow_avg_price_low_usd_mean_90                   3893.95
# moscow_avg_price_low_usd_slope_180             0.000689502
# moscow_avg_price_low_usd_slope_30              7.56591e-05
# moscow_avg_price_low_usd_slope_7               0.000112575
# moscow_avg_price_low_usd_slope_90              0.000340709
# moscow_avg_price_low_usd_std_180                   97.0017
# moscow_avg_price_low_usd_std_30                    1.83208
# moscow_avg_price_low_usd_std_7                    0.632824
# moscow_avg_price_low_usd_std_90                    25.1352
#
#                                                          2  \
# id                                                       3
# timestamp                              2011-08-27 00:00:00
# full_sq                                                 43
# life_sq                                                 29
# floor                                                    2
# max_floor                                              NaN
# material                                               NaN
# build_year                                             NaN
# num_room                                               NaN
# kitch_sq                                               NaN
# state                                                  NaN
# product_type                                             0
# sub_area                                               128
# area_m                                         4.80827e+06
# raion_popul                                         101708
# green_zone_part                                    0.11256
# indust_part                                       0.118537
# children_preschool                                    5879
# preschool_quota                                       1463
# preschool_education_centers_raion                        4
# children_school                                       6207
# school_quota                                          5580
# school_education_centers_raion                           7
# school_education_centers_top_20_raion                    0
# hospital_beds_raion                                   1183
# healthcare_centers_raion                                 1
# university_top_20_raion                                  0
# sport_objects_raion                                      5
# additional_education_raion                               1
# culture_objects_top_25                                   0
# ...                                                    ...
# moscow_avg_price_low_eur_slope_7                0.00144471
# moscow_avg_price_low_eur_slope_90              0.000576437
# moscow_avg_price_low_eur_std_180                   65.5078
# moscow_avg_price_low_eur_std_30                    19.5117
# moscow_avg_price_low_eur_std_7                     5.56885
# moscow_avg_price_low_eur_std_90                    27.9044
# moscow_avg_price_low_rub_mean_180                   108095
# moscow_avg_price_low_rub_mean_30                    114093
# moscow_avg_price_low_rub_mean_7                     116685
# moscow_avg_price_low_rub_mean_90                    110874
# moscow_avg_price_low_rub_slope_180               0.0012365
# moscow_avg_price_low_rub_slope_30               0.00403608
# moscow_avg_price_low_rub_slope_7                  0.004662
# moscow_avg_price_low_rub_slope_90               0.00184956
# moscow_avg_price_low_rub_std_180                   3493.38
# moscow_avg_price_low_rub_std_30                    1870.88
# moscow_avg_price_low_rub_std_7                     525.731
# moscow_avg_price_low_rub_std_90                    2663.04
# moscow_avg_price_low_usd_mean_180                  3820.73
# moscow_avg_price_low_usd_mean_30                   3915.57
# moscow_avg_price_low_usd_mean_7                    3918.66
# moscow_avg_price_low_usd_mean_90                   3897.27
# moscow_avg_price_low_usd_slope_180             0.000656611
# moscow_avg_price_low_usd_slope_30              9.50435e-05
# moscow_avg_price_low_usd_slope_7               0.000112575
# moscow_avg_price_low_usd_slope_90              0.000309057
# moscow_avg_price_low_usd_std_180                    92.654
# moscow_avg_price_low_usd_std_30                    2.21724
# moscow_avg_price_low_usd_std_7                    0.632824
# moscow_avg_price_low_usd_std_90                    23.2034
#
#                                                          3  \
# id                                                       4
# timestamp                              2011-09-01 00:00:00
# full_sq                                                 89
# life_sq                                                 50
# floor                                                    9
# max_floor                                              NaN
# material                                               NaN
# build_year                                             NaN
# num_room                                               NaN
# kitch_sq                                               NaN
# state                                                  NaN
# product_type                                             0
# sub_area                                                65
# area_m                                         1.25835e+07
# raion_popul                                         178473
# green_zone_part                                   0.194703
# indust_part                                      0.0697534
# children_preschool                                   13087
# preschool_quota                                       6839
# preschool_education_centers_raion                        9
# children_school                                      13670
# school_quota                                         17063
# school_education_centers_raion                          10
# school_education_centers_top_20_raion                    0
# hospital_beds_raion                                    NaN
# healthcare_centers_raion                                 1
# university_top_20_raion                                  0
# sport_objects_raion                                     17
# additional_education_raion                               6
# culture_objects_top_25                                   0
# ...                                                    ...
# moscow_avg_price_low_eur_slope_7                0.00144471
# moscow_avg_price_low_eur_slope_90              0.000611626
# moscow_avg_price_low_eur_std_180                    67.639
# moscow_avg_price_low_eur_std_30                     22.285
# moscow_avg_price_low_eur_std_7                     5.56885
# moscow_avg_price_low_eur_std_90                    29.8568
# moscow_avg_price_low_rub_mean_180                   108521
# moscow_avg_price_low_rub_mean_30                    115149
# moscow_avg_price_low_rub_mean_7                     117902
# moscow_avg_price_low_rub_mean_90                    111442
# moscow_avg_price_low_rub_slope_180              0.00131359
# moscow_avg_price_low_rub_slope_30               0.00450332
# moscow_avg_price_low_rub_slope_7                  0.004662
# moscow_avg_price_low_rub_slope_90               0.00211654
# moscow_avg_price_low_rub_std_180                   3750.52
# moscow_avg_price_low_rub_std_30                    2072.46
# moscow_avg_price_low_rub_std_7                     525.731
# moscow_avg_price_low_rub_std_90                    3041.96
# moscow_avg_price_low_usd_mean_180                  3829.18
# moscow_avg_price_low_usd_mean_30                   3916.79
# moscow_avg_price_low_usd_mean_7                    3920.13
# moscow_avg_price_low_usd_mean_90                   3901.19
# moscow_avg_price_low_usd_slope_180             0.000616269
# moscow_avg_price_low_usd_slope_30              0.000110446
# moscow_avg_price_low_usd_slope_7               0.000112575
# moscow_avg_price_low_usd_slope_90              0.000268827
# moscow_avg_price_low_usd_std_180                   87.2996
# moscow_avg_price_low_usd_std_30                    2.53239
# moscow_avg_price_low_usd_std_7                    0.632824
# moscow_avg_price_low_usd_std_90                    20.6473
#
#                                                          4
# id                                                       5
# timestamp                              2011-09-05 00:00:00
# full_sq                                                 77
# life_sq                                                 77
# floor                                                    4
# max_floor                                              NaN
# material                                               NaN
# build_year                                             NaN
# num_room                                               NaN
# kitch_sq                                               NaN
# state                                                  NaN
# product_type                                             0
# sub_area                                                 6
# area_m                                         8.39846e+06
# raion_popul                                         108171
# green_zone_part                                  0.0152337
# indust_part                                      0.0373165
# children_preschool                                    5706
# preschool_quota                                       3240
# preschool_education_centers_raion                        7
# children_school                                       6748
# school_quota                                          7770
# school_education_centers_raion                           9
# school_education_centers_top_20_raion                    0
# hospital_beds_raion                                    562
# healthcare_centers_raion                                 4
# university_top_20_raion                                  2
# sport_objects_raion                                     25
# additional_education_raion                               2
# culture_objects_top_25                                   0
# ...                                                    ...
# moscow_avg_price_low_eur_slope_7               0.000412773
# moscow_avg_price_low_eur_slope_90              0.000637665
# moscow_avg_price_low_eur_std_180                   69.1665
# moscow_avg_price_low_eur_std_30                    21.4304
# moscow_avg_price_low_eur_std_7                     2.02826
# moscow_avg_price_low_eur_std_90                    31.2189
# moscow_avg_price_low_rub_mean_180                   108872
# moscow_avg_price_low_rub_mean_30                    116040
# moscow_avg_price_low_rub_mean_7                     118719
# moscow_avg_price_low_rub_mean_90                    111925
# moscow_avg_price_low_rub_slope_180              0.00138101
# moscow_avg_price_low_rub_slope_30               0.00453288
# moscow_avg_price_low_rub_slope_7                0.00291375
# moscow_avg_price_low_rub_slope_90                0.0023259
# moscow_avg_price_low_rub_std_180                    3967.7
# moscow_avg_price_low_rub_std_30                    2085.79
# moscow_avg_price_low_rub_std_7                     343.915
# moscow_avg_price_low_rub_std_90                    3325.14
# moscow_avg_price_low_usd_mean_180                   3835.3
# moscow_avg_price_low_usd_mean_30                   3916.11
# moscow_avg_price_low_usd_mean_7                    3913.49
# moscow_avg_price_low_usd_mean_90                   3903.54
# moscow_avg_price_low_usd_slope_180             0.000580996
# moscow_avg_price_low_usd_slope_30             -1.35625e-05
# moscow_avg_price_low_usd_slope_7               -0.00138739
# moscow_avg_price_low_usd_slope_90              0.000221531
# moscow_avg_price_low_usd_std_180                   82.8229
# moscow_avg_price_low_usd_std_30                    4.38233
# moscow_avg_price_low_usd_std_7                     8.24224
# moscow_avg_price_low_usd_std_90                    18.1558
#
# [424 rows x 5 columns]
