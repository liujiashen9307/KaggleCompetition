# %% [markdown]
# # A simple personalized recommending script

# %% [markdown]
# ## Fire up packages

# %%
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas
from sklearn.cross_validation import train_test_split
import numpy
from wordcloud import WordCloud,STOPWORDS

# %% [markdown]
# ## Load data

# %%
df = pandas.read_csv('../input/techcrunch_posts.csv')
print(df.shape)
# Out:
# (39115, 11)

# %%
df.head()
# Out:
#                         authors          category  \
# 0                    Dale Chang          Startups
# 1    Ben Narasin,Jeremy Abelson  Fundings & Exits
# 2                Matthew Lynley              Apps
# 3  Matthew Lynley,Ingrid Lunden  Fundings & Exits
# 4             Megan Rose Dickey          Startups
#
#                                              content        date       id  \
# 0  \n\nTech investing isn’t what it used to be — ...  2016-10-15  1401293
# 1  \n\nThe IPO market is poised to make an almost...  2016-10-14  1399050
# 2  Under pressure from shoppers complaining about...  2016-10-14  1401954
# 3  PayPal, the giant digital payments company tha...  2016-10-14  1390023
# 4  Uber, the ridesharing behemoth that recently b...  2016-10-13  1401633
#
#                                              img_src    section  \
# 0  https://tctechcrunch2011.files.wordpress.com/2...  startups/
# 1  https://tctechcrunch2011.files.wordpress.com/2...  startups/
# 2  https://tctechcrunch2011.files.wordpress.com/2...  startups/
# 3  https://tctechcrunch2011.files.wordpress.com/2...  startups/
# 4  https://tctechcrunch2011.files.wordpress.com/2...  startups/
#
#             tags                                              title  \
# 0           data          How startups can use data to grow smarter
# 1            ipo  While the IPO market roars back, venture remai...
# 2  apoorva-mehta  Instacart reverses course, re-introducing tips...
# 3       gofundme                      PayPal mulled buying GoFundMe
# 4       lawsuits                        Uber hits another roadblock
#
#       topics                                                url
# 0        NaN  https://techcrunch.com/2016/10/15/how-startups...
# 1        NaN  https://techcrunch.com/2016/10/14/while-the-ip...
# 2  instacart  https://techcrunch.com/2016/10/14/instacart-re...
# 3     paypal  https://techcrunch.com/2016/10/14/paypal-gobuyme/
# 4       uber  https://techcrunch.com/2016/10/13/uber-hits-an...

# %% [markdown]
# ## Pre-process data

# %%
df['authors']=df['authors'].apply(lambda x: str(x).split(','))
df['tags']=df['tags'].apply(lambda x:['No tag'] if str(x)=='NaN' else str(x).split(','))
df['topics']=df['topics'].apply(lambda x: str(x).split(','))

# %%
df['content']=df['content'].fillna(0)
df=df[df['content']!=0]
df=df.reset_index(drop=True)

# %% [markdown]
# ## Build KNN model based on the content of articles

# %%
import re
import nltk
from nltk.corpus import stopwords

# %%
def to_words(content):
    letters_only = re.sub("[^a-zA-Z]", " ", content) 
    words = letters_only.lower().split()                             
    stops = set(stopwords.words("english"))                  
    meaningful_words = [w for w in words if not w in stops] 
    return( " ".join( meaningful_words ))

# %% [markdown]
# **Convert the words to tfidf matrices.**

# %%
clean_content=[]
for each in df['content']:
    clean_content.append(to_words(each))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=TfidfVectorizer()
features=tfidf.fit_transform(clean_content)

# %% [markdown]
# **Implement K-Nearest-Neighbors model**

# %%
from sklearn.neighbors import NearestNeighbors
knn=NearestNeighbors(n_neighbors=30,algorithm='brute',metric='cosine')
knn_fit=knn.fit(features)

# %% [markdown]
# ## Wrap everything up to a small, personalized recommending system

# %%
def recommend_to_user(author):
    ## Find All Authors##
    indexes=[]
    for i in range(len(df)):
        if author in df['authors'][i]:
            indexes.append(i)
    tmp_df=df.iloc[indexes,:]
    author_content=[]
    for each in tmp_df['content']:
        author_content.append(to_words(each))
    wordcloud = WordCloud(background_color='black',
                      width=3000,
                      height=2500
                     ).generate(author_content[0])
    ## Find Nearest Neighbors based on the latest aritcles the author published on the website
    Neighbors = knn_fit.kneighbors(features[indexes[0]])[1].tolist()[0][2:]
    ## Get rid of all articles that is authored/co-authored by the author and find the articles
    All_article = df.iloc[Neighbors,:]
    All_article = All_article.reset_index(drop=True)
    kept_index = []
    for j in range(len(All_article)):
        if author in All_article['authors'][j]:
            pass
        else:
            kept_index.append(j)
    Final_frame = All_article.iloc[kept_index,:]
    Final_frame=Final_frame.reset_index(drop=True)
    Selected_articles = Final_frame.iloc[0:5,:]
    
    ## Print out result directly ##
    print('==='*30)
    print('The article(s) of '+author+' is always featured by the following words')
    plt.figure(1,figsize=(8,8))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()
    print("==="*30)
    print('The top five articles recommended to '+author+' are:')
    for k in range(len(Selected_articles)):
        print(Selected_articles['title'][k]+', authored by '+Selected_articles['authors'][k][0]+' ,article can be visted at \n '+Selected_articles['url'][k])

# %% [markdown]
# ## Run a test for the recommender

# %%
recommend_to_user('Bastiaan Janmaat')
# Out:
# ==========================================================================================
# The article(s) of Bastiaan Janmaat is always featured by the following words
# ==========================================================================================
# The top five articles recommended to Bastiaan Janmaat are:
# Stop applying tech principles to consumer startups , authored by Sophie Bakalar ,article can be visted at
#  https://techcrunch.com/2016/09/02/stop-applying-tech-principles-to-consumer-startups/
# Managing Your Startup In 2016: New Rules For A New Environment, authored by Ajay Agarwal ,article can be visted at
#  https://techcrunch.com/2016/02/06/managing-your-startup-in-2016-new-rules-for-a-new-environment/
# Slack Is Just The Tip Of The Iceberg For Enterprise Tech, authored by Ross Fubini ,article can be visted at
#  https://techcrunch.com/2015/06/21/slack-is-just-the-tip-of-the-iceberg-for-enterprise-tech/
# The SaaS Success Database, authored by Neeraj Agrawal ,article can be visted at
#  https://techcrunch.com/2015/08/29/the-saas-success-database/
# Lessons from starting a company during the last downturn , authored by Alex Bard ,article can be visted at
#  https://techcrunch.com/2016/03/20/lessons-from-starting-a-company-during-the-last-downturn/

# %%
recommend_to_user('Matthew Lynley')
# Out:
# ==========================================================================================
# The article(s) of Matthew Lynley is always featured by the following words
# ==========================================================================================
# The top five articles recommended to Matthew Lynley are:
# Instacart cutting wages for shoppers starting March 14, authored by Megan Rose Dickey ,article can be visted at
#  https://techcrunch.com/2016/03/11/instacart-cutting-wages-for-shoppers-starting-march-14/
# Instacart Is Quietly Working With Third Parties To Outsource (Some Of) Its Deliveries, authored by Jordan Crook ,article can be visted at
#  https://techcrunch.com/2015/04/10/instacart-is-quietly-working-with-third-parties-to-outsource-some-of-its-deliveries/
# Instacart Offers Employee Option To Its Contractors In Atlanta, Miami And D.C., authored by Sarah Perez ,article can be visted at
#  https://techcrunch.com/2015/07/13/instacart-offers-employee-option-to-its-contractors-in-atlanta-miami-and-d-c/
# Y Combinator-Backed Instacart Wants To Be Amazon With One-Hour Delivery, authored by Rip Empson ,article can be visted at
#  https://techcrunch.com/2012/08/01/instacart/
# Y Combinator-Backed Instacart Wants To Be Amazon With One-Hour Delivery, authored by Rip Empson ,article can be visted at
#  https://techcrunch.com/2012/08/01/instacart/

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **We can find that the recommendation system is somehow making sense, if you just quickly compare the word cloud and the titles of article recommended by KNN algorithm. However, the recommender is still restricted, in terms of the following aspects:**
#
# **1. For the user who has not published many articles on the website, the recommendation system may result in a disappointing outcome.**
#
# **2. For the cases of cold-start (new users), it is more wise to use classification technique to make recommendation. Considering we do not have many user-wide data, we have to skip that.**
