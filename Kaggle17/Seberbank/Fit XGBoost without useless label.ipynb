# %%
import pandas as pd

# %%
train = pd.read_csv('train_c.csv')
test = pd.read_csv('test_c.csv')

# %%
FScore
# Out:
#                                    Feature  Score
# 0                                  full_sq   1185
# 1                                  life_sq    473
# 2                                    floor    359
# 3                               build_year    291
# 4                                max_floor    275
# 5                                 kitch_sq    163
# 6                                 num_room    129
# 7                                    state    119
# 8                          kindergarten_km    102
# 9                              railroad_km    101
# 10                           green_zone_km     95
# 11                            radiation_km     85
# 12                                material     80
# 13                                sub_area     78
# 14             public_transport_station_km     77
# 15                                  ttk_km     76
# 16                          metro_min_avto     75
# 17                           industrial_km     73
# ...

# %%
train = pd.read_csv('train_c.csv')

# %%
set(list(train['ID_railroad_terminal']))
# Out:
# {5, 32, 50, 83, 97, 101, 113, 121}
